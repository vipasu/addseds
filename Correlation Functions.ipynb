# %%
import fitsio
# %matplotlib inline
import sys
sys.path.append('/Users/vipasu/Dropbox/Research/addgals/code_for_addgals')
from routines import *
# Out:
# /usr/local/lib/python2.7/site-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))

# %%
##################################################
# read data
d0 = fits_to_pandas(fitsio.read('Becker_CAM_mock.fits', lower=True))
box_size = 250.0    
np.random.seed(111)
# load previously computed distances
densities = pd.read_csv('density_proxies.csv')

# %%
densities.columns
# Out:
# Index([u'$R_{hill}$', u'$R_{hill_{mass}}$', u'$D_{mass}$', u'$\Sigma_{1}$', u'$\Sigma_{2}$', u'$\Sigma_{5}$', u'$\Sigma_{10}$', u'$sSFR$'], dtype='object')

# %%
d = d0
d['host_dist'] = densities['$\Sigma_{mass}$'].values
d['rhill_mass'] = densities['$R_{hill_{mass}}$'].values
d['rhill'] = densities['$R_{hill}$'].values
d['s10'] = densities['$\Sigma_{10}$']
d['s1'] = densities['$\Sigma_{1}$']
d['s2'] = densities['$\Sigma_{2}$']
d['s5'] = densities['$\Sigma_{5}$']
d_train, d_test = split_octant(d, box_size)

# %%
features = ['rhill', 'mstar']
#Xtrain, ytrain, x_scaler, y_scaler = select_features(features, d_train, scaled=True)
Xtrain, ytrain = select_features(features, d_train, scaled=False)

Xtest, ytest = select_features(features, d_test, scaled=False)
#Xtest, ytest = x_scaler.transform(Xtest), y_scaler.transform(ytest)
model = DecisionTreeRegressor()
model.fit(Xtrain, ytrain)

y_hat = model.predict(Xtest)
#y_hat = y_scaler.inverse_transform(y_hat_scaled)
d_test['pred'] = y_hat
print min(y_hat), max(y_hat)
#with yaxis autoticker
correlation_ratio(d_test, '$R_{hill}$')
# Out:
# -13.0022602081 -8.60770988464

# %%
features = ['rhill_mass', 'mstar']
#Xtrain, ytrain, x_scaler, y_scaler = select_features(features, d_train, scaled=True)
Xtrain, ytrain = select_features(features, d_train, scaled=False)

Xtest, ytest = select_features(features, d_test, scaled=False)
#Xtest, ytest = x_scaler.transform(Xtest), y_scaler.transform(ytest)
model = DecisionTreeRegressor()
model.fit(Xtrain, ytrain)

y_hat = model.predict(Xtest)
#y_hat = y_scaler.inverse_transform(y_hat_scaled)
d_test['pred'] = y_hat
print min(y_hat), max(y_hat)
#with yaxis autoticker
correlation_ratio(d_test, '$R_{hill_{mass}}$')
# Out:
# -13.0022602081 -8.60770988464

# %%
features = ['s1', 'mstar']
#Xtrain, ytrain, x_scaler, y_scaler = select_features(features, d_train, scaled=True)
Xtrain, ytrain = select_features(features, d_train, scaled=False)

Xtest, ytest = select_features(features, d_test, scaled=False)
#Xtest, ytest = x_scaler.transform(Xtest), y_scaler.transform(ytest)
model = DecisionTreeRegressor()
model.fit(Xtrain, ytrain)

y_hat = model.predict(Xtest)
#y_hat = y_scaler.inverse_transform(y_hat_scaled)
d_test['pred'] = y_hat
print min(y_hat), max(y_hat)
#with yaxis autoticker
correlation_ratio(d_test, '$Sigma_{1}$')
# Out:
# -13.0022602081 -8.60770988464

# %%
features = ['s2', 'mstar']
#Xtrain, ytrain, x_scaler, y_scaler = select_features(features, d_train, scaled=True)
Xtrain, ytrain = select_features(features, d_train, scaled=False)

Xtest, ytest = select_features(features, d_test, scaled=False)
#Xtest, ytest = x_scaler.transform(Xtest), y_scaler.transform(ytest)
model = DecisionTreeRegressor()
model.fit(Xtrain, ytrain)

y_hat = model.predict(Xtest)
#y_hat = y_scaler.inverse_transform(y_hat_scaled)
d_test['pred'] = y_hat
print min(y_hat), max(y_hat)
#with yaxis autoticker
correlation_ratio(d_test, '$Sigma_{2}$')
# Out:
# -13.0022602081 -8.60770988464

# %%
features = ['s5', 'mstar']
#Xtrain, ytrain, x_scaler, y_scaler = select_features(features, d_train, scaled=True)
Xtrain, ytrain = select_features(features, d_train, scaled=False)

Xtest, ytest = select_features(features, d_test, scaled=False)
#Xtest, ytest = x_scaler.transform(Xtest), y_scaler.transform(ytest)
model = DecisionTreeRegressor()
model.fit(Xtrain, ytrain)

y_hat = model.predict(Xtest)
#y_hat = y_scaler.inverse_transform(y_hat_scaled)
d_test['pred'] = y_hat
print min(y_hat), max(y_hat)
#with yaxis autoticker
correlation_ratio(d_test, '$Sigma_{5}$')
# Out:
# -13.0022602081 -8.60770988464

# %%
features = ['s10', 'mstar']
#Xtrain, ytrain, x_scaler, y_scaler = select_features(features, d_train, scaled=True)
Xtrain, ytrain = select_features(features, d_train, scaled=False)

Xtest, ytest = select_features(features, d_test, scaled=False)
#Xtest, ytest = x_scaler.transform(Xtest), y_scaler.transform(ytest)
model = DecisionTreeRegressor()
model.fit(Xtrain, ytrain)

y_hat = model.predict(Xtest)
#y_hat = y_scaler.inverse_transform(y_hat_scaled)
d_test['pred'] = y_hat
print min(y_hat), max(y_hat)
#with yaxis autoticker
correlation_ratio(d_test, '$Sigma_{10}$')
# Out:
# -13.0022602081 -8.60770988464

# %%
features = ['s1', 's2', 'mstar']
#Xtrain, ytrain, x_scaler, y_scaler = select_features(features, d_train, scaled=True)
Xtrain, ytrain = select_features(features, d_train, scaled=False)

Xtest, ytest = select_features(features, d_test, scaled=False)
#Xtest, ytest = x_scaler.transform(Xtest), y_scaler.transform(ytest)
model = DecisionTreeRegressor()
model.fit(Xtrain, ytrain)

y_hat = model.predict(Xtest)
#y_hat = y_scaler.inverse_transform(y_hat_scaled)
d_test['pred'] = y_hat
print min(y_hat), max(y_hat)
#with yaxis autoticker
correlation_ratio(d_test, '$Sigma_{1,2}$')

# %%
features = ['s1', 's5', 'mstar']
#Xtrain, ytrain, x_scaler, y_scaler = select_features(features, d_train, scaled=True)
Xtrain, ytrain = select_features(features, d_train, scaled=False)

Xtest, ytest = select_features(features, d_test, scaled=False)
#Xtest, ytest = x_scaler.transform(Xtest), y_scaler.transform(ytest)
model = DecisionTreeRegressor()
model.fit(Xtrain, ytrain)

y_hat = model.predict(Xtest)
#y_hat = y_scaler.inverse_transform(y_hat_scaled)
d_test['pred'] = y_hat
print min(y_hat), max(y_hat)
#with yaxis autoticker
correlation_ratio(d_test, '$Sigma_{1,5}$')

# %%
features = ['s1', 's10', 'mstar']
#Xtrain, ytrain, x_scaler, y_scaler = select_features(features, d_train, scaled=True)
Xtrain, ytrain = select_features(features, d_train, scaled=False)

Xtest, ytest = select_features(features, d_test, scaled=False)
#Xtest, ytest = x_scaler.transform(Xtest), y_scaler.transform(ytest)
model = DecisionTreeRegressor()
model.fit(Xtrain, ytrain)

y_hat = model.predict(Xtest)
#y_hat = y_scaler.inverse_transform(y_hat_scaled)
d_test['pred'] = y_hat
print min(y_hat), max(y_hat)
#with yaxis autoticker
correlation_ratio(d_test, '$Sigma_{1,10}$')

# %%
features = ['s2', 's5', 'mstar']
#Xtrain, ytrain, x_scaler, y_scaler = select_features(features, d_train, scaled=True)
Xtrain, ytrain = select_features(features, d_train, scaled=False)

Xtest, ytest = select_features(features, d_test, scaled=False)
#Xtest, ytest = x_scaler.transform(Xtest), y_scaler.transform(ytest)
model = DecisionTreeRegressor()
model.fit(Xtrain, ytrain)

y_hat = model.predict(Xtest)
#y_hat = y_scaler.inverse_transform(y_hat_scaled)
d_test['pred'] = y_hat
print min(y_hat), max(y_hat)
#with yaxis autoticker
correlation_ratio(d_test, '$Sigma_{2,5}$')

# %%
features = ['s2', 's10', 'mstar']
#Xtrain, ytrain, x_scaler, y_scaler = select_features(features, d_train, scaled=True)
Xtrain, ytrain = select_features(features, d_train, scaled=False)

Xtest, ytest = select_features(features, d_test, scaled=False)
#Xtest, ytest = x_scaler.transform(Xtest), y_scaler.transform(ytest)
model = DecisionTreeRegressor()
model.fit(Xtrain, ytrain)

y_hat = model.predict(Xtest)
#y_hat = y_scaler.inverse_transform(y_hat_scaled)
d_test['pred'] = y_hat
print min(y_hat), max(y_hat)
#with yaxis autoticker
correlation_ratio(d_test, '$Sigma_{2,10}$')

# %%
features = ['s5', 's10', 'mstar']
#Xtrain, ytrain, x_scaler, y_scaler = select_features(features, d_train, scaled=True)
Xtrain, ytrain = select_features(features, d_train, scaled=False)

Xtest, ytest = select_features(features, d_test, scaled=False)
#Xtest, ytest = x_scaler.transform(Xtest), y_scaler.transform(ytest)
model = DecisionTreeRegressor()
model.fit(Xtrain, ytrain)

y_hat = model.predict(Xtest)
#y_hat = y_scaler.inverse_transform(y_hat_scaled)
d_test['pred'] = y_hat
print min(y_hat), max(y_hat)
#with yaxis autoticker
correlation_ratio(d_test, '$Sigma_{5,10}$')
